# %% [markdown]
# # StatEO 2026 EarthCODE hands-on
#
# ## Agenda
#
#
# 1. 10 mins: Introduction & Setup
#
# 2. 30 mins: Core Aspects (in Practice)
#
# - 10mins: break and catalog/asset exploration.
#
# 3. 30 mins: Cloud-native workflows and datasets
#
# 4. 10 mins: Questions, Exploration, Feedback
#
#
# ## Setup
#
# 1. git clone the repository.
#
# ```bash
# git clone https://github.com/u3ks/stateo2026
# ```
#
# 2. Install the required software environment with Conda. If you do not have Conda, install it by following these instructions (see [here](https://docs.conda.io/en/latest/miniconda.html)). Then create the environment ( this can take a few minutes ).
# ```bash
# conda env create -n pangeo_earthcode -f pangeo_earthcode.yml
# ```
#
# 3. Launch a Jupyterlab notebook server from this environment.
# ```bash
# conda activate pangeo_earthcode
# jupyter lab
# ```
#
# 4. Open a web browser and connect to the Jupyterlab provided URL (you should see it in the jupyter lab command outputs), something like: http://localhost:8888/lab?token=42fac6733c6854578b981bca3abf5152.

# %% [markdown]
# ## 1. Introduction to EarthCODE

# %%
# %%html
# <iframe src="https://docs.google.com/presentation/d/1dpgoZ_uxgPxAUeLTyauO9R-eCLMaP9AilkMDGHe0uT0/embed?start=false&loop=false&delayms=3000" frameborder="0" width="960" height="569" allowfullscreen="true" mozallowfullscreen="true" webkitallowfullscreen="true"></iframe>
# Out:
# <iframe src="https://docs.google.com/presentation/d/1dpgoZ_uxgPxAUeLTyauO9R-eCLMaP9AilkMDGHe0uT0/embed?start=false&loop=false&delayms=3000" frameborder="0" width="960" height="569" allowfullscreen="true" mozallowfullscreen="true" webkitallowfullscreen="true"></iframe>

# %% [markdown]
# ## 2. Core aspects (in practice)
#
#
# ### 2.1 STAC + Data Model:
#
#
# #### 2. 1. 1 EarthCODE + STAC : https://esa-earthcode.github.io/tutorials/stac-and-data-access/
#
# The SpatioTemporal Asset Catalog (STAC) specification was designed to establish a standard, unified language to talk about geospatial data, allowing it to be more easily searchable and queryable.
#
# #### 2. 1. 2 Open Science Catalog: https://opensciencedata.esa.int/
#
# The Open Science Data Catalog is a publicly accessible platform that enables anyone—whether or not they have a GitHub account—to discover and access Earth Observation research. It provides a transparent and structured way to explore the latest results from EO projects by organizing metadata in a consistent and harmonized format.
#
#
# #### 2.1.3 Data and Code in the OSC
#
# - Each product /dataset is described using STAC (SpatioTemporal Asset Catalog) metadata, specifically through a Collection that captures key attributes like the spatial and temporal extent, scientific context, provenance, and more. To ensure FAIRness, the catalog uses a shared dictionary and metadata standard. This structure enables users to explore products across diverse sources by theme, variable, and mission.
#
# - Each workflow is described using OGC API Records metadata, which, similar to Products captures the workflow definition, its project, related themes, variables and EO missions, related products and other related links.
#
#
# #### 2.1.4  EarthCODE library: https://esa-earthcode.github.io/earthcode-library/README.html
#
# The EarthCODE Library is a Python package developed to support the creation, validation, and search of Open Science Catalog metadata within the EarthCODE publishing workflow.

# %% [markdown]
# ## 2.2 In practice
#
# ### 2.2.3 SMARTCH4 - https://opensciencedata.esa.int/products/d13c-ch4-signatures-smart-ch4/collection
#
#         - NetCDF grids to a single Zarr store
#         - Transformation + metadata: https://esa-earthcode.github.io/tutorials/smartch4-signatures-modified/
#         - Data Access: https://github.com/ESA-EarthCODE/data_access_examples/tree/main/smart-ch4
#
# ### 2.2.3 S4AMAZONAS - https://opensciencedata.esa.int/products/sentinel1-amazonas-forest-loss/collection
#         - Weekly tiffs tiles to a single zarr store
#         - Transformation + metadata: https://esa-earthcode.github.io/tutorials/sen4amazonas/
#         - Data Access: https://github.com/ESA-EarthCODE/data_access_examples/tree/main/sen4amazonas
#
# ### 2.2.3 WAPOSAL - https://opensciencedata.esa.int/products/waposal-waves/collection
#         - Monthly NetCDFs to multiple zarrs (trajectory data)
#         - Transformation + metadata: https://esa-earthcode.github.io/tutorials/waposal/
#         - Data Access: https://github.com/ESA-EarthCODE/data_access_examples/tree/main/waposal
#
# ### 2.2.3 Lightning2EarthCare - https://opensciencedata.esa.int/products/earthcare-frame-lightning/collection
#         - Thousands of NetCDFs to monthly parquet files (trajectory data)
#         - Transformation + metadata: https://github.com/piskalab/lightning2earthcare/tree/postprocessing/postprocess
#         - Data Access: https://github.com/ESA-EarthCODE/data_access_examples/tree/main/lightning2earthcare
#         - Dashboard: https://esa-earthcode.github.io/science-hub-dashboard/
#
# ### 2.2.3 Antarctica In-sync Cube - https://discourse-earthcode.eox.at/t/antartica-insync-data-cubes/107
#         - Multiple datacubes
#         - Data Access:  https://discourse-earthcode.eox.at/t/antartica-insync-data-cubes/107
#         - Dashboard: https://esa-earthcode.github.io/polar-science-cluster-dashboard/explore/
#
#
# # 2.3 Code and Workflows: https://opensciencedata.esa.int/workflows/catalog

# %% [markdown]
# # 3. Example cloud-native optimised workflows
#
# ### Seasfire + Sentinel 2 - https://esa-earthcode.github.io/tutorials/pangeo-on-earthcode/
#
# ### Lighning2Earthcare - https://github.com/piskalab/lightning2earthcare/tree/postprocessing/postprocess
#
# ### Sen4GPP - https://github.com/EOBAS-SOTON/qygpp_tools/tree/download_remote

# %% [markdown]
# # Links:
#
# - EarthCODE: https://earthcode.esa.int/
# - Open Science Catalog - https://opensciencedata.esa.int/
# - Tutorials: https://esa-earthcode.github.io/tutorials/
# - Data Access : https://esa-earthcode.github.io/tutorials/
# - Forum: https://discourse-earthcode.eox.at/
# - EarthCODE library: https://esa-earthcode.github.io/earthcode-library/README.html
